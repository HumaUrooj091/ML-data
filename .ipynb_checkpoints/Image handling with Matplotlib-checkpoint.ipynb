# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("Omar.jpg")
print(img.shape)
plt.imshow(img)
# Out:
# (640, 496, 3)

# %%
img
# Out:
# array([[[240, 252, 232],
#         [238, 249, 232],
#         [245, 253, 238],
#         ...,
#         [244, 252, 237],
#         [246, 255, 238],
#         [246, 253, 237]],
#
#        [[238, 247, 228],
#         [237, 246, 227],
#         [240, 247, 231],
#         ...,
#         [244, 252, 237],
#         [246, 255, 238],
#         [247, 254, 238]],
#
#        [[223, 225, 204],
#         [223, 225, 204],
#         [222, 224, 203],
#         ...,
#         [244, 253, 236],
#         [246, 255, 238],
#         [247, 254, 238]],
#
#        ...,
#
#        [[252, 255, 242],
#         [252, 255, 242],
#         [252, 255, 244],
#         ...,
#         [253, 255, 250],
#         [253, 255, 250],
#         [253, 255, 250]],
#
#        [[252, 255, 242],
#         [252, 255, 242],
#         [252, 255, 244],
#         ...,
#         [253, 255, 249],
#         [253, 255, 249],
#         [253, 255, 249]],
#
#        [[252, 255, 242],
#         [252, 255, 242],
#         [252, 255, 244],
# ...

# %%
img[:,:,0] # slice for only Red
# Out:
# array([[240, 238, 245, ..., 244, 246, 246],
#        [238, 237, 240, ..., 244, 246, 247],
#        [223, 223, 222, ..., 244, 246, 247],
#        ...,
#        [252, 252, 252, ..., 253, 253, 253],
#        [252, 252, 252, ..., 253, 253, 253],
#        [252, 252, 252, ..., 253, 253, 253]], dtype=uint8)
